# %% [markdown]
# # Sensitivity analysis of model parameters

# %% [markdown]
# ## A. Imports

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

from prettytable import PrettyTable

# %% [markdown]
# Add translation to the `sys.path`:

# %%
import sys
sys.path.append(r'../')
sys.path.append(r'../translation/')

# %%
import translation

# %% [markdown]
# ## B. Ribosomes

# %%
filepath =  {150000: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, ribosomes factor 0.75_20211109_0347_150000_ribosomes_3600s.p",
             200000: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah_20211109_0858_200000_ribosomes_3600s.p",
             250000: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, ribosomes factor 1.25_20211108_2333_250000_ribosomes_3600s.p"}

# %% [markdown]
# Load results from file:

# %%
results = {}

for nribo in filepath:
    print(filepath[nribo])
    with open(filepath[nribo], 'rb') as f:
        results[nribo] = pickle.load(f)
# Out:
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, ribosomes factor 0.75_20211109_0347_150000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah_20211109_0858_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, ribosomes factor 1.25_20211108_2333_250000_ribosomes_3600s.p

# %%
results[150000].keys()
# Out:
# dict_keys(['proteome', 'peptide_bonds', 'transcriptome', 'timerange', 'timecourses', 'description', 'time_stamp', 'n_ribosomes', 'n_tRNA', 'duration'])

# %%
results[150000]['peptide_bonds']
# Out:
# 1285720976

# %%
len(results[150000]['transcriptome'])
# Out:
# 57508

# %% [markdown]
# Define protein names:

# %%
protnames = {}
blacklist = ['ribos._bound', 'ribos._free', 'tRNA_free', 'tRNA_bound', 'ATP', 'GTP', 'AMP', 'GDP', 'protein', 'peptide_bonds']

for nribo in results.keys():
    print(nribo)
    protnames[nribo] = results[nribo]['timecourses'].keys()
    for fragment in blacklist:
        protnames[nribo] = [name for name in protnames[nribo] if fragment not in name]
# Out:
# 150000
# 200000
# 250000

# %% [markdown]
# ### B.1 Protein speeds

# %% [markdown]
# Define protein speeds:

# %%
prot_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
        (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_speeds[nribo][prot] > 25: 
            print(prot, prot_speeds[nribo][prot])
# Out:
# 150000
# YKL060C 28.761064425770304
# YLR044C 38.547899159663864
# 200000
# YJL189W 27.007282913165263
# YKL152C 25.215406162464983
# YKL060C 31.57787114845938
# YOL086C 25.554699645653297
# YAL038W 27.388515406162462
# YLR044C 42.53949579831932
# 250000
# YJL189W 28.892156862745093
# YLR110C 26.039495798319326
# YKL152C 27.07899159663865
# YKL060C 33.71708683473389
# YOL086C 27.364248799002784
# YCR012W 26.57394957983193
# YAL038W 29.31428571428571
# YLR044C 45.90504201680672

# %%
transcriptome_shah = pickle.load(open('../parameters/transcriptome_shah.p', 'rb'))
orf_genomic_dict = pickle.load(open("../parameters/orf_coding.p", 'rb'))

# %%
orf_lengths = {prot: len(orf_genomic_dict[prot]) for prot in orf_genomic_dict}

# %%
prot_per_transcript_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_per_transcript_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_per_transcript_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
            transcriptome_shah[prot] / (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_per_transcript_speeds[nribo][prot] > 0.05: 
            print(prot, prot_per_transcript_speeds[nribo][prot])
# Out:
# 150000
# YDR461W 0.053068500127323656
# YLR388W 0.05006672826198542
# 200000
# YDR461W 0.057431457431457424
# YLR388W 0.054819833692639354
# YDR224C 0.05267884931750478
# YJL158C 0.05085200746965452
# 250000
# YDR461W 0.06231219760631525
# YJL189W 0.052340863881784584
# YLR388W 0.05866660800445832
# YDR224C 0.055404383975812536
# YFL014W 0.050606909430438836
# YJL158C 0.05416083099906628

# %%
def plot_speed_efficiency(prot_speeds, prot_per_transcript_speeds):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams['axes.edgecolor'] = 'grey'

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121)
    n, bins, patches = ax.hist(prot_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_speeds.values())+0.0001), 
                                                      np.log10(max(prot_speeds.values())), 25), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_speeds.values())+0.0001, max(prot_speeds.values())])
    ax.set_xlabel('Translation speed [proteins/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0001, 670, "A", fontsize=16, weight="bold")

    ax = fig.add_subplot(122)
    n, bins, patches = ax.hist(prot_per_transcript_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_per_transcript_speeds.values())+0.0001), 
                                                      np.log10(max(prot_per_transcript_speeds.values())), 32), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_per_transcript_speeds.values())+0.002, max(prot_per_transcript_speeds.values())])
    ax.set_xlabel('Translation efficiency [proteins/transcript/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0009, 600, "B", fontsize=16, weight="bold")

    #plt.show()
    plt.savefig('../plots/translation_efficiencies.pdf', bbox_inches='tight') # TODO: fixed name is not nice

# %% [markdown]
# Five-number summary:

# %%
def fivenum(data):
    """Five-number summary."""
    return np.percentile(list(data), [0, 25, 50, 75, 100], interpolation='midpoint')

# %%
print("Protein speeds:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_speeds[nribo].values())))
print(t)
# Out:
# Protein speeds:
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+
# | Ribosomes |          Min           |         25%          |        Median        |         75%         |        Max         |
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+
# |   150000  | 0.00028011204481792715 | 0.009523809523809523 | 0.02352974131290354  | 0.07282913165266106 | 38.547899159663864 |
# |   200000  | 0.00028011204481792715 | 0.010364145658263303 | 0.026050420168067225 | 0.08123249299719887 | 42.53949579831932  |
# |   250000  | 0.00028011204481792715 | 0.011204481792717085 | 0.028011204481792715 | 0.08641456582633052 | 45.90504201680672  |
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+

# %%
print("Protein speeds per transcript:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_per_transcript_speeds[nribo].values())))
    plot_speed_efficiency(prot_speeds[nribo], prot_per_transcript_speeds[nribo])
print(t)
# Out:
# Protein speeds per transcript:
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# | Ribosomes |          Min           |          25%          |        Median        |         75%          |         Max          |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# |   150000  | 8.670134720554888e-05  | 0.0050420168067226885 | 0.007563025210084033 | 0.011344537815126048 | 0.053068500127323656 |
# |   200000  | 0.00010337468320661597 |  0.005602240896358543 | 0.008403361344537815 | 0.012476043048798466 | 0.057431457431457424 |
# |   250000  | 0.00014005602240896358 |  0.006018723278785197 | 0.009041520967458305 | 0.013352007469654526 | 0.06231219760631525  |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+

# %% [markdown]
# Calculation of elasticities w.r.t. ribosome count:

# %% [markdown]
# Elasticity down $\Delta \% X / \Delta \% n_{\mathrm{Ribo}}$:

# %%
delta_percent_prot_speed_median_down = (fivenum(prot_speeds[200000].values())[2] - 
                                                       fivenum(prot_speeds[150000].values())[2]) / fivenum(prot_speeds[200000].values())[2]
elasticity_prot_speed_median_down = delta_percent_prot_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed: {elasticity_prot_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed: 38.7%

# %%
delta_percent_prot_per_transcript_speed_median_down = (fivenum(prot_per_transcript_speeds[200000].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[150000].values())[2]) / fivenum(prot_per_transcript_speeds[200000].values())[2]
elasticity_prot_per_transcript_speed_median_down = delta_percent_prot_per_transcript_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed per transcript: 40.0%

# %% [markdown]
# Elasticity up $\Delta \% X / \Delta \% n_{\mathrm{Ribo}}$:

# %%
delta_percent_prot_speed_median_up = (fivenum(prot_speeds[250000].values())[2] - 
                                                       fivenum(prot_speeds[200000].values())[2]) / fivenum(prot_speeds[200000].values())[2]
elasticity_prot_speed_median_up = delta_percent_prot_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed: {elasticity_prot_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed: 30.1%

# %%
delta_percent_prot_per_transcript_speed_median_up = (fivenum(prot_per_transcript_speeds[250000].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[200000].values())[2]) / fivenum(prot_per_transcript_speeds[200000].values())[2]
elasticity_prot_per_transcript_speed_median_up = delta_percent_prot_per_transcript_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed per transcript: 30.4%

# %% [markdown]
# ### B.2 Ribosome speeds

# %%
df1 = pd.DataFrame.from_dict(orf_lengths.items())
df1.columns = ['name', 'ORF length [nts]']

# %%
transcript_tic_toc = {}
transcript_tic_toc_averages = {}
transcript_df = {}
temp_df = {}
gene_tic_toc = {}
gene_tic_toc_df = {}
df = {}
ribo_speed_dict = {}

for nribo in results.keys():
    transcript_tic_toc[nribo] = {transcript.index: transcript.tic_toc for transcript in results[nribo]['transcriptome']}
    transcript_tic_toc_averages[nribo] = {index: np.mean([toc-tic for (tic, toc) in transcript_tic_toc[nribo][index]]) for index in transcript_tic_toc[nribo]}
    # transcript_df[nribo] = pd.DataFrame(transcript_tic_toc_averages[nribo].values(), index=transcript_tic_toc_averages[nribo].keys())
    transcript_df[nribo] = pd.DataFrame(pd.Series(transcript_tic_toc_averages[nribo]))
    transcript_df[nribo].columns = ['tic_toc']
    temp_df[nribo] = pd.DataFrame(pd.Series({transcript.index: transcript.geneID for transcript in results[nribo]['transcriptome']}))
    temp_df[nribo].columns = ['geneID']
    transcript_df[nribo] = pd.merge(transcript_df[nribo], temp_df[nribo], left_index=True, right_index=True, how='outer')
    gene_tic_toc[nribo] = transcript_df[nribo].groupby('geneID').mean().to_dict()['tic_toc']
    gene_tic_toc_df[nribo] = pd.DataFrame.from_dict(gene_tic_toc[nribo].items())
    gene_tic_toc_df[nribo].columns = ['name', 'tic toc [s]']
    df[nribo] = pd.merge(gene_tic_toc_df[nribo], df1, left_on='name', right_on='name', how='outer')
    ribo_speed_dict[nribo] = {geneID: orf_lengths[geneID] / 3.0 / gene_tic_toc[nribo][geneID] for geneID in gene_tic_toc[nribo]}
# Out:
# C:\Program Files\Python39\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def plot_time_finish_ribosome_speed(ribo_speed_dict, df):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.edgecolor'] = 'black'
    plt.rcParams['axes.labelcolor'] = 'black'
    plt.rcParams['xtick.color'] = 'black'
    plt.rcParams['ytick.color'] = 'black'
    plt.rcParams['grid.linestyle'] = '-.'
    plt.rcParams['grid.color'] = 'grey'
    #plt.rcParams['figure.facecolor'] = 'white'

    hfont = {'fontname':'FreeSans'}

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121, facecolor='white')
    ax.scatter(df['ORF length [nts]'], df['tic toc [s]'], alpha=0.8, color='navy', edgecolor='steelblue', linewidth=1)
    ax.set_xlabel('ORF length [nts]', fontsize=16, **hfont)
    ax.set_ylabel('Time to finish protein [s]', fontsize=16, **hfont)
    plt.setp(ax.get_xticklabels(), fontsize=16, **hfont)
    plt.setp(ax.get_yticklabels(), fontsize=16, **hfont)
    ax.set_yscale('log')
    ax.set_xscale('log')

    ax = fig.add_subplot(122, facecolor='white')
    plt.hist(ribo_speed_dict.values(), 
             bins=np.arange(min(ribo_speed_dict.values()), max(ribo_speed_dict.values()), 0.5), 
                               color='navy', edgecolor='steelblue')
    ax.set_xlabel('Ribosome speed [codons/s]', fontsize=16, **hfont)
    ax.set_ylabel('Frequency', fontsize=16, **hfont)
    plt.setp(plt.gca().get_xticklabels(), fontsize=16, **hfont)
    plt.setp(plt.gca().get_yticklabels(), fontsize=16, **hfont)
    
    #plt.show()
    #plt.savefig("ribosome_speeds.pdf")

# %%
for nribo in results.keys():
    print(nribo)
    plot_time_finish_ribosome_speed(ribo_speed_dict[nribo], df[nribo])
# Out:
# 150000
# 200000
# 250000
# findfont: Font family ['FreeSans'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Slopes/intercepts of time to finish vs. length plots:

# %%
for nribo in results.keys():
    print(nribo)
    Y = np.log(df[nribo]['tic toc [s]'])
    X = np.log(df[nribo]['ORF length [nts]'])
    X = sm.add_constant(X)

    model = sm.OLS(Y, X, missing='drop')
    res = model.fit()
    print(res.params)
# Out:
# 150000
# const              -3.056239
# ORF length [nts]    1.008089
# dtype: float64
# 200000
# const              -3.055218
# ORF length [nts]    1.007360
# dtype: float64
# 250000
# const              -3.042343
# ORF length [nts]    1.005020
# dtype: float64

# %% [markdown]
# Almost identical.

# %% [markdown]
# Average ribosome speeds:

# %%
for nribo in results.keys():
    print(nribo)
    speeds = np.array(list(ribo_speed_dict[nribo].values()))
    print(np.nanmean(speeds))
# Out:
# 150000
# 6.80906155936347
# 200000
# 6.83991307581582
# 250000
# 6.866220097778142

# %% [markdown]
# Elasticities of ribosome speeds:

# %% [markdown]
# Elasticity up:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[250000].values()))) - np.nanmean(np.array(list(ribo_speed_dict[200000].values())))) / 0.25
# Out:
# 0.10522808784928728

# %% [markdown]
# Elasticity down:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[200000].values()))) - np.nanmean(np.array(list(ribo_speed_dict[150000].values())))) / 0.25
# Out:
# 0.12340606580940161

# %% [markdown]
# ## C. Initiation rates

# %% [markdown]
# Load new sensitivity analysis:

# %%
filepath =  {0.75: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah factor 0.75_20211117_0708_200000_ribosomes_3600s.p",
             1.00: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah_20211109_0858_200000_ribosomes_3600s.p",
             1.25: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah factor 1.25_20211109_2133_200000_ribosomes_3600s.p"}

# %% [markdown]
# Load results from file:

# %%
results = {}

for nribo in filepath:
    print(filepath[nribo])
    with open(filepath[nribo], 'rb') as f:
        results[nribo] = pickle.load(f)
# Out:
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah factor 0.75_20211117_0708_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah_20211109_0858_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah factor 1.25_20211109_2133_200000_ribosomes_3600s.p

# %% [markdown]
# Define protein names:

# %%
protnames = {}
blacklist = ['ribos._bound', 'ribos._free', 'tRNA_free', 'tRNA_bound', 'ATP', 'GTP', 'AMP', 'GDP', 'protein', 'peptide_bonds']

for nribo in results.keys():
    print(nribo)
    protnames[nribo] = results[nribo]['timecourses'].keys()
    for fragment in blacklist:
        protnames[nribo] = [name for name in protnames[nribo] if fragment not in name]
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# ### C.1 Protein speeds

# %% [markdown]
# Define protein speeds:

# %%
prot_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
        (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_speeds[nribo][prot] > 25: 
            print(prot, prot_speeds[nribo][prot])
# Out:
# 0.75
# YJL189W 27.841736694677866
# YLR110C 25.005882352941175
# YKL152C 25.92773109243697
# YKL060C 32.39467787114845
# YOL086C 26.450420168067225
# YCR012W 25.36282020756593
# YAL038W 28.09131652661064
# YLR044C 43.73697478991596
# 1.0
# YJL189W 27.007282913165263
# YKL152C 25.215406162464983
# YKL060C 31.57787114845938
# YOL086C 25.554699645653297
# YAL038W 27.388515406162462
# YLR044C 42.53949579831932
# 1.25
# YJL189W 26.49159663865546
# YKL060C 30.820168067226888
# YOL086C 25.199159663865544
# YAL038W 26.67647058823529
# YLR044C 41.8750700280112

# %%
transcriptome_shah = pickle.load(open('../parameters/transcriptome_shah.p', 'rb'))
orf_genomic_dict = pickle.load(open("../parameters/orf_coding.p", 'rb'))

# %%
orf_lengths = {prot: len(orf_genomic_dict[prot]) for prot in orf_genomic_dict}

# %%
prot_per_transcript_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_per_transcript_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_per_transcript_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
            transcriptome_shah[prot] / (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_per_transcript_speeds[nribo][prot] > 0.05: 
            print(prot, prot_per_transcript_speeds[nribo][prot])
# Out:
# 0.75
# YDR461W 0.05890841184958832
# YJL189W 0.05043792879470628
# YLR388W 0.05725724844911786
# YDR224C 0.05296785380818994
# YJL158C 0.05165732959850606
# 1.0
# YDR461W 0.057431457431457424
# YLR388W 0.054819833692639354
# YDR224C 0.05267884931750478
# YJL158C 0.05085200746965452
# 1.25
# YDR461W 0.057142857142857134
# YLR388W 0.05391350257380438
# YDR224C 0.05052687741763371

# %%
def plot_speed_efficiency(prot_speeds, prot_per_transcript_speeds):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams['axes.edgecolor'] = 'grey'

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121)
    n, bins, patches = ax.hist(prot_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_speeds.values())+0.0001), 
                                                      np.log10(max(prot_speeds.values())), 25), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_speeds.values())+0.0001, max(prot_speeds.values())])
    ax.set_xlabel('Translation speed [proteins/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0001, 670, "A", fontsize=16, weight="bold")

    ax = fig.add_subplot(122)
    n, bins, patches = ax.hist(prot_per_transcript_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_per_transcript_speeds.values())+0.0001), 
                                                      np.log10(max(prot_per_transcript_speeds.values())), 32), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_per_transcript_speeds.values())+0.002, max(prot_per_transcript_speeds.values())])
    ax.set_xlabel('Translation efficiency [proteins/transcript/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0009, 600, "B", fontsize=16, weight="bold")

    #plt.show()
    plt.savefig('../plots/translation_efficiencies.pdf', bbox_inches='tight') # TODO: fixed name is not nice

# %% [markdown]
# Five-number summary:

# %%
def fivenum(data):
    """Five-number summary."""
    return np.percentile(list(data), [0, 25, 50, 75, 100], interpolation='midpoint')

# %%
print("Protein speeds:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_speeds[nribo].values())))
print(t)
# Out:
# Protein speeds:
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+
# | Ribosomes |          Min           |         25%          |        Median        |         75%         |        Max        |
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+
# |    0.75   | 0.00028011204481792715 | 0.010644257703081231 | 0.026610644257703077 | 0.08235294117647057 | 43.73697478991596 |
# |    1.0    | 0.00028011204481792715 | 0.010364145658263303 | 0.026050420168067225 | 0.08123249299719887 | 42.53949579831932 |
# |    1.25   | 0.00028011204481792715 | 0.010084033613445377 | 0.025770308123249295 | 0.08053277586332505 |  41.8750700280112 |
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+

# %%
print("Protein speeds per transcript:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_per_transcript_speeds[nribo].values())))
    plot_speed_efficiency(prot_speeds[nribo], prot_per_transcript_speeds[nribo])
print(t)
# Out:
# Protein speeds per transcript:
# +-----------+------------------------+----------------------+----------------------+----------------------+----------------------+
# | Ribosomes |          Min           |         25%          |        Median        |         75%          |         Max          |
# +-----------+------------------------+----------------------+----------------------+----------------------+----------------------+
# |    0.75   | 0.00014005602240896358 | 0.005658263305322128 | 0.008683473389355741 | 0.012698501624116829 | 0.05890841184958832  |
# |    1.0    | 0.00010337468320661597 | 0.005602240896358543 | 0.008403361344537815 | 0.012476043048798466 | 0.057431457431457424 |
# |    1.25   | 0.00010670935040682938 | 0.005378151260504201 | 0.008216619981325862 | 0.012324929971988793 | 0.057142857142857134 |
# +-----------+------------------------+----------------------+----------------------+----------------------+----------------------+

# %% [markdown]
# Calculation of elasticities w.r.t. ribosome count:

# %% [markdown]
# Elasticity down $\Delta \% X / \Delta \% p_{\mathrm{init}}$:

# %%
delta_percent_prot_speed_median_down = (fivenum(prot_speeds[1.00].values())[2] - 
                                                       fivenum(prot_speeds[0.75].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_down = delta_percent_prot_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed: {elasticity_prot_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed: -8.6%

# %%
delta_percent_prot_per_transcript_speed_median_down = (fivenum(prot_per_transcript_speeds[1.00].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[0.75].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_down = delta_percent_prot_per_transcript_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed per transcript: -13.3%

# %% [markdown]
# Elasticity up $\Delta \% X / \Delta \% p_{\mathrm{init}}$:

# %%
delta_percent_prot_speed_median_up = (fivenum(prot_speeds[1.25].values())[2] - 
                                                       fivenum(prot_speeds[1.00].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_up = delta_percent_prot_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed: {elasticity_prot_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed: -4.3%

# %%
delta_percent_prot_per_transcript_speed_median_up = (fivenum(prot_per_transcript_speeds[1.25].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[1.00].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_up = delta_percent_prot_per_transcript_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed per transcript: -8.9%

# %% [markdown]
# Probably higher initiation rate -> more initiations -> more collisions and queueing near start codon.

# %% [markdown]
# ### C.2 Ribosome speeds

# %%
df1 = pd.DataFrame.from_dict(orf_lengths.items())
df1.columns = ['name', 'ORF length [nts]']

# %%
transcript_tic_toc = {}
transcript_tic_toc_averages = {}
transcript_df = {}
temp_df = {}
gene_tic_toc = {}
gene_tic_toc_df = {}
df = {}
ribo_speed_dict = {}

for nribo in results.keys():
    transcript_tic_toc[nribo] = {transcript.index: transcript.tic_toc for transcript in results[nribo]['transcriptome']}
    transcript_tic_toc_averages[nribo] = {index: np.mean([toc-tic for (tic, toc) in transcript_tic_toc[nribo][index]]) for index in transcript_tic_toc[nribo]}
    # transcript_df[nribo] = pd.DataFrame(transcript_tic_toc_averages[nribo].values(), index=transcript_tic_toc_averages[nribo].keys())
    transcript_df[nribo] = pd.DataFrame(pd.Series(transcript_tic_toc_averages[nribo]))
    transcript_df[nribo].columns = ['tic_toc']
    temp_df[nribo] = pd.DataFrame(pd.Series({transcript.index: transcript.geneID for transcript in results[nribo]['transcriptome']}))
    temp_df[nribo].columns = ['geneID']
    transcript_df[nribo] = pd.merge(transcript_df[nribo], temp_df[nribo], left_index=True, right_index=True, how='outer')
    gene_tic_toc[nribo] = transcript_df[nribo].groupby('geneID').mean().to_dict()['tic_toc']
    gene_tic_toc_df[nribo] = pd.DataFrame.from_dict(gene_tic_toc[nribo].items())
    gene_tic_toc_df[nribo].columns = ['name', 'tic toc [s]']
    df[nribo] = pd.merge(gene_tic_toc_df[nribo], df1, left_on='name', right_on='name', how='outer')
    ribo_speed_dict[nribo] = {geneID: orf_lengths[geneID] / 3.0 / gene_tic_toc[nribo][geneID] for geneID in gene_tic_toc[nribo]}
# Out:
# C:\Program Files\Python39\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def plot_time_finish_ribosome_speed(ribo_speed_dict, df):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.edgecolor'] = 'black'
    plt.rcParams['axes.labelcolor'] = 'black'
    plt.rcParams['xtick.color'] = 'black'
    plt.rcParams['ytick.color'] = 'black'
    plt.rcParams['grid.linestyle'] = '-.'
    plt.rcParams['grid.color'] = 'grey'
    #plt.rcParams['figure.facecolor'] = 'white'

    hfont = {'fontname':'FreeSans'}

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121, facecolor='white')
    ax.scatter(df['ORF length [nts]'], df['tic toc [s]'], alpha=0.8, color='navy', edgecolor='steelblue', linewidth=1)
    ax.set_xlabel('ORF length [nts]', fontsize=16, **hfont)
    ax.set_ylabel('Time to finish protein [s]', fontsize=16, **hfont)
    plt.setp(ax.get_xticklabels(), fontsize=16, **hfont)
    plt.setp(ax.get_yticklabels(), fontsize=16, **hfont)
    ax.set_yscale('log')
    ax.set_xscale('log')

    ax = fig.add_subplot(122, facecolor='white')
    plt.hist(ribo_speed_dict.values(), 
             bins=np.arange(min(ribo_speed_dict.values()), max(ribo_speed_dict.values()), 0.5), 
                               color='navy', edgecolor='steelblue')
    ax.set_xlabel('Ribosome speed [codons/s]', fontsize=16, **hfont)
    ax.set_ylabel('Frequency', fontsize=16, **hfont)
    plt.setp(plt.gca().get_xticklabels(), fontsize=16, **hfont)
    plt.setp(plt.gca().get_yticklabels(), fontsize=16, **hfont)
    
    #plt.show()
    #plt.savefig("ribosome_speeds.pdf")

# %%
for nribo in results.keys():
    print(nribo)
    plot_time_finish_ribosome_speed(ribo_speed_dict[nribo], df[nribo])
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# Slopes/intercepts of time to finish vs. length plots:

# %%
for nribo in results.keys():
    print(nribo)
    Y = np.log(df[nribo]['tic toc [s]'])
    X = np.log(df[nribo]['ORF length [nts]'])
    X = sm.add_constant(X)

    model = sm.OLS(Y, X, missing='drop')
    res = model.fit()
    print(res.params)
# Out:
# 0.75
# const              -3.040193
# ORF length [nts]    1.005194
# dtype: float64
# 1.0
# const              -3.055218
# ORF length [nts]    1.007360
# dtype: float64
# 1.25
# const              -3.049401
# ORF length [nts]    1.006624
# dtype: float64

# %% [markdown]
# Almost identical.

# %% [markdown]
# Average ribosome speeds:

# %%
for nribo in results.keys():
    print(nribo)
    speeds = np.array(list(ribo_speed_dict[nribo].values()))
    print(np.nanmean(speeds))
# Out:
# 0.75
# 6.8424188319379775
# 1.0
# 6.83991307581582
# 1.25
# 6.835588628939361

# %% [markdown]
# Elasticities of ribosome speeds:

# %% [markdown]
# Elasticity up:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.25].values()))) - np.nanmean(np.array(list(ribo_speed_dict[1.00].values())))) / 0.25
# Out:
# -0.017297787505839324

# %% [markdown]
# Elasticity down:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.00].values()))) - np.nanmean(np.array(list(ribo_speed_dict[0.75].values())))) / 0.25
# Out:
# -0.010023024488628351

# %% [markdown]
# Can be considered to be zero.

# %% [markdown]
# ## D. tRNAs

# %% [markdown]
# Load new sensitivity analysis:

# %%
filepath =  {0.75: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, tRNAs factor 0.75_20211118_0630_200000_ribosomes_3600s.p",
             1.00: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah_20211109_0858_200000_ribosomes_3600s.p",
             1.25: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, tRNAs factor 1.25_20211118_1705_200000_ribosomes_3600s.p"}

# %% [markdown]
# Load results from file:

# %%
results = {}

for nribo in filepath:
    print(filepath[nribo])
    with open(filepath[nribo], 'rb') as f:
        results[nribo] = pickle.load(f)
# Out:
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, tRNAs factor 0.75_20211118_0630_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah_20211109_0858_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, tRNAs factor 1.25_20211118_1705_200000_ribosomes_3600s.p

# %% [markdown]
# Define protein names:

# %%
protnames = {}
blacklist = ['ribos._bound', 'ribos._free', 'tRNA_free', 'tRNA_bound', 'ATP', 'GTP', 'AMP', 'GDP', 'protein', 'peptide_bonds']

for nribo in results.keys():
    print(nribo)
    protnames[nribo] = results[nribo]['timecourses'].keys()
    for fragment in blacklist:
        protnames[nribo] = [name for name in protnames[nribo] if fragment not in name]
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# ### D.1 Protein speeds

# %% [markdown]
# Define protein speeds:

# %%
prot_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
        (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_speeds[nribo][prot] > 25: 
            print(prot, prot_speeds[nribo][prot])
# Out:
# 0.75
# YJL189W 27.051820728291315
# YKL152C 25.23025210084033
# YKL060C 31.71008403361344
# YOL086C 25.56162464985994
# YAL038W 27.309523809523807
# YLR044C 42.65518207282913
# 1.0
# YJL189W 27.007282913165263
# YKL152C 25.215406162464983
# YKL060C 31.57787114845938
# YOL086C 25.554699645653297
# YAL038W 27.388515406162462
# YLR044C 42.53949579831932
# 1.25
# YJL189W 26.931092436974787
# YKL152C 25.19943977591036
# YKL060C 31.55462184873949
# YOL086C 25.481232492997197
# YAL038W 27.210644257703077
# YLR044C 42.78067226890756

# %%
transcriptome_shah = pickle.load(open('../parameters/transcriptome_shah.p', 'rb'))
orf_genomic_dict = pickle.load(open("../parameters/orf_coding.p", 'rb'))

# %%
orf_lengths = {prot: len(orf_genomic_dict[prot]) for prot in orf_genomic_dict}

# %%
prot_per_transcript_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_per_transcript_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_per_transcript_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
            transcriptome_shah[prot] / (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_per_transcript_speeds[nribo][prot] > 0.05: 
            print(prot, prot_per_transcript_speeds[nribo][prot])
# Out:
# 0.75
# YDR461W 0.05795772854596383
# YLR388W 0.05491076011556454
# YDR224C 0.05279445111377884
# 1.0
# YDR461W 0.057431457431457424
# YLR388W 0.054819833692639354
# YDR224C 0.05267884931750478
# YJL158C 0.05085200746965452
# 1.25
# YDR461W 0.058840505899329425
# YLR388W 0.054997286872864315
# YDR224C 0.050931483704592946
# YJL158C 0.05031512605042016

# %%
def plot_speed_efficiency(prot_speeds, prot_per_transcript_speeds):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams['axes.edgecolor'] = 'grey'

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121)
    n, bins, patches = ax.hist(prot_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_speeds.values())+0.0001), 
                                                      np.log10(max(prot_speeds.values())), 25), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_speeds.values())+0.0001, max(prot_speeds.values())])
    ax.set_xlabel('Translation speed [proteins/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0001, 670, "A", fontsize=16, weight="bold")

    ax = fig.add_subplot(122)
    n, bins, patches = ax.hist(prot_per_transcript_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_per_transcript_speeds.values())+0.0001), 
                                                      np.log10(max(prot_per_transcript_speeds.values())), 32), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_per_transcript_speeds.values())+0.002, max(prot_per_transcript_speeds.values())])
    ax.set_xlabel('Translation efficiency [proteins/transcript/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0009, 600, "B", fontsize=16, weight="bold")

    #plt.show()
    plt.savefig('../plots/translation_efficiencies.pdf', bbox_inches='tight') # TODO: fixed name is not nice

# %% [markdown]
# Five-number summary:

# %%
def fivenum(data):
    """Five-number summary."""
    return np.percentile(list(data), [0, 25, 50, 75, 100], interpolation='midpoint')

# %%
print("Protein speeds:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_speeds[nribo].values())))
print(t)
# Out:
# Protein speeds:
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+
# | Ribosomes |          Min           |         25%          |        Median        |         75%         |        Max        |
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+
# |    0.75   | 0.00028011204481792715 | 0.010364145658263303 | 0.026050420168067225 | 0.08095238095238094 | 42.65518207282913 |
# |    1.0    | 0.00028011204481792715 | 0.010364145658263303 | 0.026050420168067225 | 0.08123249299719887 | 42.53949579831932 |
# |    1.25   | 0.00028011204481792715 | 0.010364145658263303 | 0.02633053221288515  | 0.08011204481792716 | 42.78067226890756 |
# +-----------+------------------------+----------------------+----------------------+---------------------+-------------------+

# %%
print("Protein speeds per transcript:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_per_transcript_speeds[nribo].values())))
    plot_speed_efficiency(prot_speeds[nribo], prot_per_transcript_speeds[nribo])
print(t)
# Out:
# Protein speeds per transcript:
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# | Ribosomes |          Min           |          25%          |        Median        |         75%          |         Max          |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# |    0.75   | 0.00010670935040682938 | 0.0054621848739495795 | 0.008403361344537815 | 0.012464985994397758 | 0.05795772854596383  |
# |    1.0    | 0.00010337468320661597 |  0.005602240896358543 | 0.008403361344537815 | 0.012476043048798466 | 0.057431457431457424 |
# |    1.25   | 0.0001100440176070428  | 0.0054621848739495795 | 0.008403361344537815 | 0.01247037276449041  | 0.058840505899329425 |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+

# %% [markdown]
# Calculation of elasticities w.r.t. ribosome count:

# %% [markdown]
# Elasticity down $\Delta \% X / \Delta \% n_{\mathrm{tRNA}}$:

# %%
delta_percent_prot_speed_median_down = (fivenum(prot_speeds[1.00].values())[2] - 
                                                       fivenum(prot_speeds[0.75].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_down = delta_percent_prot_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed: {elasticity_prot_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed: 0.0%

# %%
delta_percent_prot_per_transcript_speed_median_down = (fivenum(prot_per_transcript_speeds[1.00].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[0.75].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_down = delta_percent_prot_per_transcript_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed per transcript: 0.0%

# %% [markdown]
# Elasticity up $\Delta \% X / \Delta \% n_{\mathrm{tRNA}}$:

# %%
delta_percent_prot_speed_median_up = (fivenum(prot_speeds[1.25].values())[2] - 
                                                       fivenum(prot_speeds[1.00].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_up = delta_percent_prot_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed: {elasticity_prot_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed: 4.3%

# %%
delta_percent_prot_per_transcript_speed_median_up = (fivenum(prot_per_transcript_speeds[1.25].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[1.00].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_up = delta_percent_prot_per_transcript_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed per transcript: 0.0%

# %% [markdown]
# ### D.2 Ribosome speeds

# %%
df1 = pd.DataFrame.from_dict(orf_lengths.items())
df1.columns = ['name', 'ORF length [nts]']

# %%
transcript_tic_toc = {}
transcript_tic_toc_averages = {}
transcript_df = {}
temp_df = {}
gene_tic_toc = {}
gene_tic_toc_df = {}
df = {}
ribo_speed_dict = {}

for nribo in results.keys():
    transcript_tic_toc[nribo] = {transcript.index: transcript.tic_toc for transcript in results[nribo]['transcriptome']}
    transcript_tic_toc_averages[nribo] = {index: np.mean([toc-tic for (tic, toc) in transcript_tic_toc[nribo][index]]) for index in transcript_tic_toc[nribo]}
    # transcript_df[nribo] = pd.DataFrame(transcript_tic_toc_averages[nribo].values(), index=transcript_tic_toc_averages[nribo].keys())
    transcript_df[nribo] = pd.DataFrame(pd.Series(transcript_tic_toc_averages[nribo]))
    transcript_df[nribo].columns = ['tic_toc']
    temp_df[nribo] = pd.DataFrame(pd.Series({transcript.index: transcript.geneID for transcript in results[nribo]['transcriptome']}))
    temp_df[nribo].columns = ['geneID']
    transcript_df[nribo] = pd.merge(transcript_df[nribo], temp_df[nribo], left_index=True, right_index=True, how='outer')
    gene_tic_toc[nribo] = transcript_df[nribo].groupby('geneID').mean().to_dict()['tic_toc']
    gene_tic_toc_df[nribo] = pd.DataFrame.from_dict(gene_tic_toc[nribo].items())
    gene_tic_toc_df[nribo].columns = ['name', 'tic toc [s]']
    df[nribo] = pd.merge(gene_tic_toc_df[nribo], df1, left_on='name', right_on='name', how='outer')
    ribo_speed_dict[nribo] = {geneID: orf_lengths[geneID] / 3.0 / gene_tic_toc[nribo][geneID] for geneID in gene_tic_toc[nribo]}
# Out:
# C:\Program Files\Python39\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def plot_time_finish_ribosome_speed(ribo_speed_dict, df):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.edgecolor'] = 'black'
    plt.rcParams['axes.labelcolor'] = 'black'
    plt.rcParams['xtick.color'] = 'black'
    plt.rcParams['ytick.color'] = 'black'
    plt.rcParams['grid.linestyle'] = '-.'
    plt.rcParams['grid.color'] = 'grey'
    #plt.rcParams['figure.facecolor'] = 'white'

    hfont = {'fontname':'FreeSans'}

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121, facecolor='white')
    ax.scatter(df['ORF length [nts]'], df['tic toc [s]'], alpha=0.8, color='navy', edgecolor='steelblue', linewidth=1)
    ax.set_xlabel('ORF length [nts]', fontsize=16, **hfont)
    ax.set_ylabel('Time to finish protein [s]', fontsize=16, **hfont)
    plt.setp(ax.get_xticklabels(), fontsize=16, **hfont)
    plt.setp(ax.get_yticklabels(), fontsize=16, **hfont)
    ax.set_yscale('log')
    ax.set_xscale('log')

    ax = fig.add_subplot(122, facecolor='white')
    plt.hist(ribo_speed_dict.values(), 
             bins=np.arange(min(ribo_speed_dict.values()), max(ribo_speed_dict.values()), 0.5), 
                               color='navy', edgecolor='steelblue')
    ax.set_xlabel('Ribosome speed [codons/s]', fontsize=16, **hfont)
    ax.set_ylabel('Frequency', fontsize=16, **hfont)
    plt.setp(plt.gca().get_xticklabels(), fontsize=16, **hfont)
    plt.setp(plt.gca().get_yticklabels(), fontsize=16, **hfont)
    
    #plt.show()
    #plt.savefig("ribosome_speeds.pdf")

# %%
for nribo in results.keys():
    print(nribo)
    plot_time_finish_ribosome_speed(ribo_speed_dict[nribo], df[nribo])
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# Slopes/intercepts of time to finish vs. length plots:

# %%
for nribo in results.keys():
    print(nribo)
    Y = np.log(df[nribo]['tic toc [s]'])
    X = np.log(df[nribo]['ORF length [nts]'])
    X = sm.add_constant(X)

    model = sm.OLS(Y, X, missing='drop')
    res = model.fit()
    print(res.params)
# Out:
# 0.75
# const              -3.050072
# ORF length [nts]    1.006635
# dtype: float64
# 1.0
# const              -3.055218
# ORF length [nts]    1.007360
# dtype: float64
# 1.25
# const              -3.051773
# ORF length [nts]    1.006916
# dtype: float64

# %% [markdown]
# Almost identical.

# %% [markdown]
# Average ribosome speeds:

# %%
for nribo in results.keys():
    print(nribo)
    speeds = np.array(list(ribo_speed_dict[nribo].values()))
    print(np.nanmean(speeds))
# Out:
# 0.75
# 6.839248616780442
# 1.0
# 6.83991307581582
# 1.25
# 6.837629223023916

# %% [markdown]
# Elasticities of ribosome speeds:

# %% [markdown]
# Elasticity up:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.25].values()))) - np.nanmean(np.array(list(ribo_speed_dict[1.00].values())))) / 0.25
# Out:
# -0.00913541116761607

# %% [markdown]
# Elasticity down:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.00].values()))) - np.nanmean(np.array(list(ribo_speed_dict[0.75].values())))) / 0.25
# Out:
# 0.002657836141512604

# %% [markdown]
# Can be considered to be zero.

# %% [markdown]
# ## E. mRNAs

# %% [markdown]
# Load new sensitivity analysis:

# %%
filepath =  {0.75: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, mRNAs factor 0.75_20211124_0125_200000_ribosomes_3600s.p",
             1.00: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah_20211109_0858_200000_ribosomes_3600s.p",
             1.25: "../results/updated Shah transcriptome, full exome, no decay, updated initiation "
             "rates according to Shah, mRNAs factor 1.25_20211124_1825_200000_ribosomes_3600s.p"}

# %% [markdown]
# Load results from file:

# %%
results = {}

for nribo in filepath:
    print(filepath[nribo])
    with open(filepath[nribo], 'rb') as f:
        results[nribo] = pickle.load(f)
# Out:
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, mRNAs factor 0.75_20211124_0125_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah_20211109_0858_200000_ribosomes_3600s.p
# ../results/updated Shah transcriptome, full exome, no decay, updated initiation rates according to Shah, mRNAs factor 1.25_20211124_1825_200000_ribosomes_3600s.p

# %% [markdown]
# Define protein names:

# %%
protnames = {}
blacklist = ['ribos._bound', 'ribos._free', 'tRNA_free', 'tRNA_bound', 'ATP', 'GTP', 'AMP', 'GDP', 'protein', 'peptide_bonds']

for nribo in results.keys():
    print(nribo)
    protnames[nribo] = results[nribo]['timecourses'].keys()
    for fragment in blacklist:
        protnames[nribo] = [name for name in protnames[nribo] if fragment not in name]
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# ### E.1 Protein speeds

# %% [markdown]
# Define protein speeds:

# %%
prot_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
        (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_speeds[nribo][prot] > 25: 
            print(prot, prot_speeds[nribo][prot])
# Out:
# 0.75
# YKL060C 26.972366559755738
# YLR044C 36.251820728291314
# 1.0
# YJL189W 27.007282913165263
# YKL152C 25.215406162464983
# YKL060C 31.57787114845938
# YOL086C 25.554699645653297
# YAL038W 27.388515406162462
# YLR044C 42.53949579831932
# 1.25
# YJL189W 30.904481792717082
# YLR110C 27.845938375350137
# YKL152C 28.79831932773109
# YKL060C 35.85546218487394
# YOL086C 29.07351643580442
# YCR012W 28.3344537815126
# YAL038W 31.052380952380947
# YLR044C 48.72605042016806

# %%
transcriptome_shah = pickle.load(open('../parameters/transcriptome_shah.p', 'rb'))
orf_genomic_dict = pickle.load(open("../parameters/orf_coding.p", 'rb'))

# %%
orf_lengths = {prot: len(orf_genomic_dict[prot]) for prot in orf_genomic_dict}

# %%
prot_per_transcript_speeds = {}

for nribo in results.keys():
    print(nribo)
    prot_per_transcript_speeds[nribo] = {}
    for prot in protnames[nribo]:
        start, stop = 599, len(results[nribo]['timecourses'][prot]) - 1  # 599 to exclude the "burn in" phase
        prot_per_transcript_speeds[nribo][prot] = (results[nribo]['timecourses'][prot][stop] - results[nribo]['timecourses'][prot][start]) / \
            transcriptome_shah[prot] / (1.0 * results[nribo]['timerange'][stop] - results[nribo]['timerange'][start])
        if prot_per_transcript_speeds[nribo][prot] > 0.05: 
            print(prot, prot_per_transcript_speeds[nribo][prot])
# Out:
# 0.75
# 1.0
# YDR461W 0.057431457431457424
# YLR388W 0.054819833692639354
# YDR224C 0.05267884931750478
# YJL158C 0.05085200746965452
# 1.25
# YDR461W 0.06513029454205924
# YJL189W 0.05598638005927008
# YLR388W 0.06367342748617771
# YLR325C 0.052911587170079294
# YLR264W 0.05166162464985993
# YLR061W 0.05205821459018389
# YDR224C 0.059392645947267786
# YFL014W 0.053314659197012136
# YEL034W 0.050641101511026944
# YJL158C 0.05753384687208216

# %%
def plot_speed_efficiency(prot_speeds, prot_per_transcript_speeds):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams['axes.edgecolor'] = 'grey'

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121)
    n, bins, patches = ax.hist(prot_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_speeds.values())+0.0001), 
                                                      np.log10(max(prot_speeds.values())), 25), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_speeds.values())+0.0001, max(prot_speeds.values())])
    ax.set_xlabel('Translation speed [proteins/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0001, 670, "A", fontsize=16, weight="bold")

    ax = fig.add_subplot(122)
    n, bins, patches = ax.hist(prot_per_transcript_speeds.values(), 
                               bins = 10**np.linspace(np.log10(min(prot_per_transcript_speeds.values())+0.0001), 
                                                      np.log10(max(prot_per_transcript_speeds.values())), 32), 
                               edgecolor='white')
    ax.set_xscale("log")
    ax.set_xlim([min(prot_per_transcript_speeds.values())+0.002, max(prot_per_transcript_speeds.values())])
    ax.set_xlabel('Translation efficiency [proteins/transcript/s]', fontsize=16)
    ax.set_ylabel('Protein count', fontsize=16)
    plt.setp(ax.get_xticklabels(), fontsize=16)
    plt.setp(ax.get_yticklabels(), fontsize=16)
    plt.text(0.0009, 600, "B", fontsize=16, weight="bold")

    #plt.show()
    plt.savefig('../plots/translation_efficiencies.pdf', bbox_inches='tight') # TODO: fixed name is not nice

# %% [markdown]
# Five-number summary:

# %%
def fivenum(data):
    """Five-number summary."""
    return np.percentile(list(data), [0, 25, 50, 75, 100], interpolation='midpoint')

# %%
print("Protein speeds:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_speeds[nribo].values())))
print(t)
# Out:
# Protein speeds:
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+
# | Ribosomes |          Min           |         25%          |        Median        |         75%         |        Max         |
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+
# |    0.75   | 0.00028011204481792715 | 0.010924369747899159 | 0.022969187675070026 | 0.06722689075630252 | 36.251820728291314 |
# |    1.0    | 0.00028011204481792715 | 0.010364145658263303 | 0.026050420168067225 | 0.08123249299719887 | 42.53949579831932  |
# |    1.25   | 0.00028011204481792715 | 0.009803921568627449 | 0.02941176470588235  | 0.09411764705882351 | 48.72605042016806  |
# +-----------+------------------------+----------------------+----------------------+---------------------+--------------------+

# %%
print("Protein speeds per transcript:")
t = PrettyTable(["Ribosomes", 'Min', '25%', 'Median', '75%', 'Max'])
for nribo in results.keys():
    t.add_row([nribo] + list(fivenum(prot_per_transcript_speeds[nribo].values())))
    plot_speed_efficiency(prot_speeds[nribo], prot_per_transcript_speeds[nribo])
print(t)
# Out:
# Protein speeds per transcript:
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# | Ribosomes |          Min           |          25%          |        Median        |         75%          |         Max          |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+
# |    0.75   | 0.00010337468320661597 | 0.0053221288515406156 | 0.007843137254901959 | 0.011255411255411253 | 0.04901960784313725  |
# |    1.0    | 0.00010337468320661597 |  0.005602240896358543 | 0.008403361344537815 | 0.012476043048798466 | 0.057431457431457424 |
# |    1.25   | 0.00013672327010048825 |  0.005508870214752567 | 0.008963585434173669 | 0.013795518207282911 | 0.06513029454205924  |
# +-----------+------------------------+-----------------------+----------------------+----------------------+----------------------+

# %% [markdown]
# Calculation of elasticities w.r.t. ribosome count:

# %% [markdown]
# Elasticity down $\Delta \% X / \Delta \% n_{\mathrm{mRNA}}$:

# %%
delta_percent_prot_speed_median_down = (fivenum(prot_speeds[1.00].values())[2] - 
                                                       fivenum(prot_speeds[0.75].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_down = delta_percent_prot_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed: {elasticity_prot_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed: 47.3%

# %%
delta_percent_prot_per_transcript_speed_median_down = (fivenum(prot_per_transcript_speeds[1.00].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[0.75].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_down = delta_percent_prot_per_transcript_speed_median_down / 0.25
print(f"Elasticity downwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_down:.1%}")
# Out:
# Elasticity downwards median of protein speed per transcript: 26.7%

# %% [markdown]
# Elasticity up $\Delta \% X / \Delta \% n_{\mathrm{mRNA}}$:

# %%
delta_percent_prot_speed_median_up = (fivenum(prot_speeds[1.25].values())[2] - 
                                                       fivenum(prot_speeds[1.00].values())[2]) / fivenum(prot_speeds[1.00].values())[2]
elasticity_prot_speed_median_up = delta_percent_prot_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed: {elasticity_prot_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed: 51.6%

# %%
delta_percent_prot_per_transcript_speed_median_up = (fivenum(prot_per_transcript_speeds[1.25].values())[2] - 
                                                       fivenum(prot_per_transcript_speeds[1.00].values())[2]) / fivenum(prot_per_transcript_speeds[1.00].values())[2]
elasticity_prot_per_transcript_speed_median_up = delta_percent_prot_per_transcript_speed_median_up / 0.25
print(f"Elasticity upwards median of protein speed per transcript: {elasticity_prot_per_transcript_speed_median_up:.1%}")
# Out:
# Elasticity upwards median of protein speed per transcript: 26.7%

# %% [markdown]
# ### E.2 Ribosome speeds

# %%
df1 = pd.DataFrame.from_dict(orf_lengths.items())
df1.columns = ['name', 'ORF length [nts]']

# %%
transcript_tic_toc = {}
transcript_tic_toc_averages = {}
transcript_df = {}
temp_df = {}
gene_tic_toc = {}
gene_tic_toc_df = {}
df = {}
ribo_speed_dict = {}

for nribo in results.keys():
    transcript_tic_toc[nribo] = {transcript.index: transcript.tic_toc for transcript in results[nribo]['transcriptome']}
    transcript_tic_toc_averages[nribo] = {index: np.mean([toc-tic for (tic, toc) in transcript_tic_toc[nribo][index]]) for index in transcript_tic_toc[nribo]}
    # transcript_df[nribo] = pd.DataFrame(transcript_tic_toc_averages[nribo].values(), index=transcript_tic_toc_averages[nribo].keys())
    transcript_df[nribo] = pd.DataFrame(pd.Series(transcript_tic_toc_averages[nribo]))
    transcript_df[nribo].columns = ['tic_toc']
    temp_df[nribo] = pd.DataFrame(pd.Series({transcript.index: transcript.geneID for transcript in results[nribo]['transcriptome']}))
    temp_df[nribo].columns = ['geneID']
    transcript_df[nribo] = pd.merge(transcript_df[nribo], temp_df[nribo], left_index=True, right_index=True, how='outer')
    gene_tic_toc[nribo] = transcript_df[nribo].groupby('geneID').mean().to_dict()['tic_toc']
    gene_tic_toc_df[nribo] = pd.DataFrame.from_dict(gene_tic_toc[nribo].items())
    gene_tic_toc_df[nribo].columns = ['name', 'tic toc [s]']
    df[nribo] = pd.merge(gene_tic_toc_df[nribo], df1, left_on='name', right_on='name', how='outer')
    ribo_speed_dict[nribo] = {geneID: orf_lengths[geneID] / 3.0 / gene_tic_toc[nribo][geneID] for geneID in gene_tic_toc[nribo]}
# Out:
# C:\Program Files\Python39\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def plot_time_finish_ribosome_speed(ribo_speed_dict, df):
    plt.rcParams['figure.figsize'] = (12, 5)
    plt.rcParams['axes.edgecolor'] = 'black'
    plt.rcParams['axes.labelcolor'] = 'black'
    plt.rcParams['xtick.color'] = 'black'
    plt.rcParams['ytick.color'] = 'black'
    plt.rcParams['grid.linestyle'] = '-.'
    plt.rcParams['grid.color'] = 'grey'
    #plt.rcParams['figure.facecolor'] = 'white'

    hfont = {'fontname':'FreeSans'}

    fig = plt.figure()
    fig.subplots_adjust(wspace=0.35)

    ax = fig.add_subplot(121, facecolor='white')
    ax.scatter(df['ORF length [nts]'], df['tic toc [s]'], alpha=0.8, color='navy', edgecolor='steelblue', linewidth=1)
    ax.set_xlabel('ORF length [nts]', fontsize=16, **hfont)
    ax.set_ylabel('Time to finish protein [s]', fontsize=16, **hfont)
    plt.setp(ax.get_xticklabels(), fontsize=16, **hfont)
    plt.setp(ax.get_yticklabels(), fontsize=16, **hfont)
    ax.set_yscale('log')
    ax.set_xscale('log')

    ax = fig.add_subplot(122, facecolor='white')
    plt.hist(ribo_speed_dict.values(), 
             bins=np.arange(min(ribo_speed_dict.values()), max(ribo_speed_dict.values()), 0.5), 
                               color='navy', edgecolor='steelblue')
    ax.set_xlabel('Ribosome speed [codons/s]', fontsize=16, **hfont)
    ax.set_ylabel('Frequency', fontsize=16, **hfont)
    plt.setp(plt.gca().get_xticklabels(), fontsize=16, **hfont)
    plt.setp(plt.gca().get_yticklabels(), fontsize=16, **hfont)
    
    #plt.show()
    #plt.savefig("ribosome_speeds.pdf")

# %%
for nribo in results.keys():
    print(nribo)
    plot_time_finish_ribosome_speed(ribo_speed_dict[nribo], df[nribo])
# Out:
# 0.75
# 1.0
# 1.25

# %% [markdown]
# Slopes/intercepts of time to finish vs. length plots:

# %%
for nribo in results.keys():
    print(nribo)
    Y = np.log(df[nribo]['tic toc [s]'])
    X = np.log(df[nribo]['ORF length [nts]'])
    X = sm.add_constant(X)

    model = sm.OLS(Y, X, missing='drop')
    res = model.fit()
    print(res.params)
# Out:
# 0.75
# const              -3.037165
# ORF length [nts]    1.004044
# dtype: float64
# 1.0
# const              -3.055218
# ORF length [nts]    1.007360
# dtype: float64
# 1.25
# const              -3.056137
# ORF length [nts]    1.008006
# dtype: float64

# %% [markdown]
# Almost identical.

# %% [markdown]
# Average ribosome speeds:

# %%
for nribo in results.keys():
    print(nribo)
    speeds = np.array(list(ribo_speed_dict[nribo].values()))
    print(np.nanmean(speeds))
# Out:
# 0.75
# 6.879050261683547
# 1.0
# 6.83991307581582
# 1.25
# 6.813278186534014

# %% [markdown]
# Elasticities of ribosome speeds:

# %% [markdown]
# Elasticity up:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.25].values()))) - np.nanmean(np.array(list(ribo_speed_dict[1.00].values())))) / 0.25
# Out:
# -0.10653955712722407

# %% [markdown]
# Elasticity down:

# %%
(np.nanmean(np.array(list(ribo_speed_dict[1.00].values()))) - np.nanmean(np.array(list(ribo_speed_dict[0.75].values())))) / 0.25
# Out:
# -0.15654874347090697
